# %%
# Concatenation - joining two tring together - we use + operator
# Both the operands should be of string type, if you are performing concatenation on strings
# str1 = 'Python'
# str2 = 'Class'
# print(str1+" "+str2)

# num1 = 9
# print(str1 + num1)  # Type Error

# String formatting
# a = 100
# b = 200
# # sum of 10 and 20 is 30
# print('The sum of a={} and b={} is c={}'.format(a,b,a+b))
# print(f'The sum of {a} and {b} is {a+b}')


# Repetition - Repeating a string - we use * operator
# one the operands should be of string type and other operand shoud be of int type, if you are performing Repetition on strings
# str1 = 'Python'
# num1 = 3
# print(str1*num1)

# Type Error 
# print(str1*3.0)

# Reverse of string
# print('Python'[::-1] * 4)

# To check if two string are having equal content
# print(str1 == 'Python')
# print(str1 != 'Python')
# print(str1 == 'python')

# Logical operation on string -and, or not
# Logical operators always check for the logic and logics will alway be evaluated either as True or False
# Truth table - and - False
# True and True = True
# True and False = False
# False and True = False
# False and False = False


# # Truth table - or - True
# True or True = True
# True or False = True
# False or True = True
# False and False = False

# # Truth table - not
# not True = False
# not False = True

# print(str1 == 'Python')
# print(str1 != 'Python')

# print(str1 == 'Python' and str1 != 'Python')
# print(str1 == 'Python' and 10<20)

# print(str1 == 'Python' or str1 != 'Python')
# print(str1 == 'Python' or 10<20)

# Applying logical operation on string object 
# If you are not taking an expression which is getting evauated as either True or False then the result will always be the values you are passing
# A and B - A if A is False else B


# print('A' and 'B')
# print('' and 'B')
# print('A' and '')
# print('' and ' ')

# A or B - A if A is True else B
# print('A' or 'B')
# print('' or 'B')
# print('A' or '')
# print('' or ' ')


# print(not True)
# print(not False)
# print(not 'A')
# print(not '')

# None == null in Java




# Boolean - string - 
# '' - empty string is always False rest all values are True

# bool() which use to check whether a value is True or False
# print(bool(0))
# print(bool(0.0))
# print(bool(0.0+0.0j))
# print(bool(0.0000000000000000000000001))

#string
# print(bool(""))
# print(bool('A'))
# print(bool(' '))

# Comparison Operation - <,>, <=, >=
# returns Boolean value
# Comparison happens on the string based on the ASCII value
# length wise

str1 = 'Python'
str2 = 'Python'
# # print(str1<=str2)

str3 = 'python'
str4 = 'PythoN'
# # print(str1>str3)
# # print(str1 < str4)

str5 = 'Pythor'
# print(str1 > str5)

str6 = 'Rytho'
# print(str1 > str6)


# To get the ASCII equivalent code for a character - not allowed for a group of characters
# print(ord('A'))
# print(ord('P'))
# print(ord('p'))
# print(ord(' '))
# print(ord('a'))

# To get the corresponding character value from the ASCII value, will take only between 0 - 127

# print(chr(112))
# print(chr(121))
# print(chr(123))
# print(chr(65))


# Difference between Comparison vs equality operator

# print(str1 == str2)
# print(str1 == str4)
# print(str1 > str4)


# Membership operation - in, not in
# used to check a charcater or group of characters are part of the string or not
# rteurns only True pr False - Boolen values

my_str= 'Peter Piper picked a peck of pickled peppers'
# print('P' in my_str)
# print('Peter' in my_str)
# print('Peter' not in my_str)
# print('Z' in my_str)
# print('Z' not in my_str)
# print('Pr' in my_str)

# identity operation - is, is not
# check whether the id of both the operands are same then returns True else returns False
# str1 = 'Python'
# str2 = 'Python'
# print(id(str1))
# # print(id(str2))
# print(str1 is str2)
# print(str1 is str2)



# str3 = 'Python$'
# str4 = 'Python$'
# print(id(str3))
# print(id(str4))
# print(str3 is str4)
# print(id(str3[-1]))
# print(id(str4[-1]))


# object reusability concept in Python
# objects has to be resused rather than creating again and again
# int - -5 to 256
# None
# True and False
# string - A - Z, a to z, and 0 - 9, _

# Not available for float, complex, derived data types

# a = 100
# b = 100
# print(id(a))
# print(id(b))
# print(a is b)


# a = 1000
# b = 1000
# print(id(a))
# print(id(b))
# print(a is b)
# print(a is not b)

# a = '$$'
# b = '$$'
# print(a is b)
# print(id(a[0]))
# print(id(b[-1]))

# String is immutable object - String can not be modified - Item assignment is not possible
# String can not be modified - modification will not be done in the same string object at same id

my_str = 'Python'
# Item Assignment
# my_str[0] = 'J' # TypeError: 'str' object does not support item assignment
# mod_str = my_str.swapcase()
# print(mod_str, id(mod_str))
# print(my_str, id(my_str))



# Item assignment is possible into mutable objects - for example list
# lst = [10,20,30,40]
# print(lst, id(lst))
# lst[0] = 100
# print(lst, id(lst))

# String methdos
# print(dir(str))

#   'center',  'encode', 'expandtabs',  
#     'format_map',  'ljust', 
#      'maketrans', 'partition', , 'rjust', 'rpartition',  'splitlines',   'translate',  'zfill'


# 'capitalize', 'casefold', 'lower', 'swapcase', 'title', 'upper' 'endswith', 'startswith', 
my_str = 'Peter Piper picked a peck of pickled peppers'
# cap_str = my_str.capitalize()    # Capitalizes the first character of the first word
# print(cap_str)
# print(my_str)


# casefold is more aggressive than lower function
# case_str = my_str.casefold()
# low_str = my_str.lower()
# print(case_str, id(case_str))
# print(low_str, id(low_str))
# print(my_str, id(my_str))

# my_str = 'der Fluß'
# print(my_str.lower())
# print(my_str.casefold())

# swap_str = my_str.swapcase()
# print(swap_str)


# title_str = my_str.title()   # Converts first letter of every word into capital case
# print(title_str)

# upper_str = my_str.upper()
# print(upper_str)

# startswith and endswith returns boolean values
# print(my_str.startswith('P'))
# print(my_str.startswith('Peter'))
# print(my_str.startswith('Zeter'))

# print(my_str.endswith('s'))
# print(my_str.endswith('peppers'))
# print(my_str.endswith('zeppers'))


# print(my_str.startswith('picked', 12))


# 'isalnum' - returns True if string is alphanumeric else False
# 'isalpha' - returns True if string is alphabets
# 'isascii' - returns True of the string belongs to ASCII table
# 'isdecimal', 'isdigit', 'isnumeric', - whether a number is numeral or not, 
# 'isidentifier' - returns True if it is a valid identifier, excception returns True for keywords
#  islower' - returns True if all character are in lower case
# 'isprintable' - returns True of the string is printable
# 'isspace' - returns True if string is a space character
# 'istitle' - returns True if string is in title case
# 'isupper' 0- returns True if string is in upper case

# print('Python987'.isalnum())
# print('Python'.isalnum())
# print('987'.isalnum())
# print('Python987%$'.isalnum())

# print('Python987'.isalpha())
# print('987'.isalpha())
# print('Python'.isalpha())


# print('der Fluß'.isascii())
# print('der Fluss'.isascii())

# print('num'.isidentifier())
# print('num1'.isidentifier())
# print('1num'.isidentifier())

# print('This is \nPython class'.isprintable())
# print('This is \\nPython class'.isprintable())

# print('This is \nPython class')
# print('This is \\nPython class')


# print('0b1010'.isdecimal())
# print('10'.isdecimal())

# print('  '.isspace())
# print('\n\t\v\f'.isspace())
# print('\n')
# print('\t')
# print('\v')
# print('\f')
# print('\r')


 

# find, rfind, index, rindex
# these methods returns the index of first occurrbec of substring which you are looking for into the given string
# find and index method looks for subtring from left to right
# rfind and rindex methods looks for subtring from  righ to left
# The difference between find and index method is if substring is not found then find method returns -1
            # whereas index method returns valueError


my_str = 'Peter Piper picked a peck of pickled peppers'
# print(my_str.find('P'))
# print(my_str.find('Piper'))
# print(my_str.find('pi', 13, 27))
# print(my_str.find('pi'))
# print(my_str.rfind('pi'))

# print(my_str.index('P'))
# print(my_str.index('Piper'))
# print(my_str.index('pi', 13, 27))
# print(my_str.index('pi'))
# print(my_str.rindex('pi'))

# 'count',
# used to count the number of times a substring is repeating
# print(my_str.count('p'))
# print(my_str.count('pe'))
# print(my_str.count('pe', 10, 29))


# 'lstrip', 'strip', 'rstrip',
# These methods are used to remove the unneccessary space from the begining or from the end of the string
# does not remove ths unneccessary spaces from in between the strings
# strip - removes spaces from both side
# lstrip - removes spaces from left side
# rstrip - removes spaces from right side

# my_str1 = '      This is Python      class        '
# print(my_str1.strip())
# print(my_str1.lstrip())
# print(my_str1.rstrip())

# 'replace', - used to replace a. substring from the given string
# print(my_str)
# print(my_str.replace('p', 'z', 3))


# 'join',  'rsplit',  'split',
# split is used to split the string from the specified deleimiter - returns a list after splitting a string
# join is used to join a list into a string format - returns a string after joining a list

my_str = 'Peter Piper picked a peck of pickled peppers'
# print(my_str.split(' '))
spl_str = my_str.split('p')
# print(spl_str)

# print(my_str.rsplit('p'))

# only join method in whole string which has different syntax
# 'del'.join(lst/tuple)
# 'p'.join(spl_str)

# ' '.join(my_str.split())


# my_str = 'Peter Piper picked a peck of pickled peppers'
# ind = -1
# count = 0
# while True:
#     ind = my_str.find('p', ind+1)
#     if ind == -1:
#         break
#     else:
#         count +=1
#         print(ind)
# print('Total count of p is ', count)



my_str[::-1].replace('p', 'z', 3)[::-1]
# Out:
# 'Peter Piper picked a peck of pickled zezzers'

# %%
# To take the input from user - input()
# input() - by default converts everything into string type

# str1 = input('Enter a string: ')
# str2 = input('Enter a string: ')
# print(type(str1))
# print(type(str2))
# print(str1 == str2)

# num1 = int(input('Enter a number: '))
# num2 = int(input('Enter a number: '))
# print(num1, type(num1))
# print(num2, type(num2))
# print(num1+num2)

# num1 = float(input('Enter a number: '))
# num2 = int(input('Enter a number: '))
# print(num1, type(num1))
# print(num2, type(num2))
# print(num1+num2)

# Want ot take two complex numbers - 10+20j, 30j, 20+0j
# num1 = complex(float(input('Enter 1st number')), float(input('Enter 2nd number')))
# num2 = complex(float(input('Enter 1st number')), float(input('Enter 2nd number')))
# num3 = complex(float(input('Enter 1st number')))
# print(num1, type(num1))
# print(num2, type(num2))

# Taking string data from the user
str1 = input('ENter a string: ')
print(str1, type(str1))
# Out:
# ENter a string: Python
# Python <class 'str'>
